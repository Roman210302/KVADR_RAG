# %%
# %pip install langchain_milvus
# %pip install langchain-ollama

# %%
# %pip install -r requirements.txt

# %pip install -qU  langchain_milvus
# %pip install -U langchain-ollama

# %%
import os
from typing import List, Dict
from langchain.embeddings import HuggingFaceEmbeddings
# from langchain_huggingface import HuggingFaceEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain_milvus import Milvus
from langchain.document_loaders import TextLoader
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from huggingface_hub import hf_hub_download
from vllm import LLM, SamplingParams
from langchain_community.llms import VLLM
from datasets import Dataset
from ragas.metrics import faithfulness, answer_relevancy, context_precision, context_utilization, context_recall, answer_correctness 
from ragas import evaluate
from ragas.run_config import RunConfig
import pandas as pd
from tqdm import tqdm
import subprocess
import pickle

from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

from langchain_community.llms import LlamaCpp
from langchain_core.callbacks import CallbackManager, StreamingStdOutCallbackHandler

from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import CrossEncoderReranker
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from langchain.retrievers import BM25Retriever
from langchain.retrievers import EnsembleRetriever
from langchain_core.documents import Document
from langchain_core.documents.compressor import BaseDocumentCompressor
from pydantic import BaseModel

import warnings
warnings.filterwarnings("ignore")

# %%
config = {
    'model_name': 'gemma-2-9b-it-simpo-q4',  # llama3.1-8b-q4 / gemma-2-9b-it-simpo-q4 / tlite-q4
    'embed_model_name_short': 'e5l', # e5l (multilingual-e5-large) / bgem3 (bge-m3) / ubgem3 (USER-bge-m3)
    'chunk_size': 512, # либо 512/128, 1024/256, 256/64 (или ?2048/256?)
    'chunk_overlap': 128,
    'llm_framework': 'VLLM', # VLLM, LLamaCpp, Ollama
    'vectorstore_name': 'MILVUS', # база данных MILVUS / FAISS
    'retriever_name': 'ensemble', # 'vectorstore' / 'ensemble' (BM25 + vertorstore)
    'retriever_k': 4,
    'compressor_name': 'gluing_chunks', # None / 'cross_encoder_reranker' / 'gluing_chunks' 
    'chain_type': 'stuff',
}

ensemble_config = {
    'ensemble_retrievers_names': ['BM25', 'vectorstore'], # применяется только если retriever_name=ensemble
    'ensemble_retrievers_weights': [0.3, 0.7], # применяется только если retriever_name=ensemble
}

llama_config = {
    'repo_id': 'lmstudio-community/Meta-Llama-3.1-8B-Instruct-GGUF',
    'filename': 'Meta-Llama-3.1-8B-Instruct-Q4_K_M.gguf',
    'tokenizer': 'hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4'
    }

gemma_config = {
    'repo_id': "mannix/gemma2-9b-simpo",
    'llm_framework': 'Ollama'
    }

tlite_config = {
    'repo_id': 'mradermacher/saiga_tlite_8b-GGUF',
    'filename': 'saiga_tlite_8b.Q4_K_M.gguf',
    'tokenizer': 'IlyaGusev/saiga_tlite_8b'
    }

reranker_config = {
    'reranker_model': "BAAI/bge-reranker-v2-m3",
    'retriever_k': 30
}


def update_config_with_model(config, llama_config, gemma_config, tlite_config):
    if config['model_name'] == 'llama3.1-8b-q4':
        config.update(llama_config)
    elif config['model_name'] == 'gemma-2-9b-it-simpo-q4':
        config.update(gemma_config)
    elif config['model_name'] == 'tlite-q4':
        config.update(tlite_config)
    else:
        ValueError('Incorrect model_name: choose from llama3.1-8b-q4, gemma-2-9b-it-simpo-q4, or tlite-q4')
    
    if config['embed_model_name_short'] == 'e5l':
        config['embedding_model'] = "intfloat/multilingual-e5-large"
    elif config['embed_model_name_short'] == 'bgem3':
        config['embedding_model'] = 'BAAI/bge-m3'
    # elif config['embed_model_name_short'] == 'ubgem3':
    #     config['embedding_model'] = 'deepvk/USER-bge-m3'
    
    if config['retriever_name'] == 'ensemble':
        config.update(ensemble_config)
    
    if config['compressor_name'] == 'cross_encoder_reranker':
        config.update(reranker_config)


update_config_with_model(config, llama_config, gemma_config, tlite_config)

# %%
# внутри используется реранкер и эвристики
class ChunkCompressor(BaseDocumentCompressor):
    chunks: list
    chunk_overlap: int

    def compress_documents(self, chunks, query=None, callbacks=None):
        outputs = []
        for chunk in chunks:
            current_id = chunk.metadata['chunk_index']
            new_chunk = Document(page_content=chunk.page_content, metadata=chunk.metadata)
            
            # Добавление контекста слева
            if current_id > 0:
                left_neighbor = self.chunks[current_id - 1]
                new_chunk.page_content = left_neighbor.page_content[:-config['chunk_overlap']] + new_chunk.page_content
            
            # Добавление контекста справа
            if current_id < len(self.chunks) - 1:
                right_neighbor = self.chunks[current_id + 1]
                new_chunk.page_content += right_neighbor.page_content[config['chunk_overlap']:]
            
            outputs.append(new_chunk)
        
        return outputs

# %%
class CustomRAGPipeline:
    def __init__(self, 
                 documents_path: str,
                 config: dict,
                 recalc_embedding: bool = False,
                 recalc_chunks: bool = False,
                 ):
        
        self.config = config
        self.documents_path = documents_path
        self.embedding_model = self.config['embedding_model']
        
        self.vectorstore = None
        self.qa_chain = None

        self.embeddings = HuggingFaceEmbeddings(model_name=self.embedding_model)
        self.chunks = None
        
        self.retriever = None
        self.compressor = None #склейка соседних чанков к найденным и затем реранкер (оба - при необходимости)

        self.vectorstore_path = '_'.join([self.config['embed_model_name_short'], 
                                          self.config['vectorstore_name'], 
                                          str(self.config['chunk_size']), 
                                          str(self.config['chunk_overlap'])]
                                        )
        
        self.chunks_path = '_'.join(['chunks', 
                                     str(self.config['chunk_size']), 
                                     str(self.config['chunk_overlap'])]
                                   ) + '.pkl'

        if not recalc_embedding:
            if os.path.exists(self.vectorstore_path) and self.config['vectorstore_name'] == 'FAISS':
                self.vectorstore = FAISS.load_local(self.vectorstore_path, self.embeddings, allow_dangerous_deserialization=True)
            elif os.path.isfile(f"{self.vectorstore_path}.db") and self.config['vectorstore_name'] == 'MILVUS':
                self.vectorstore = Milvus(
                    self.embeddings,
                    connection_args={"uri": f"./{self.vectorstore_path}.db"},
                    collection_name="RAG",
                )
        
        if not recalc_chunks:
            if os.path.exists(self.chunks_path):
                with open(self.chunks_path, "rb") as f:
                    self.chunks = pickle.load(f)

        if self.config['llm_framework'] == 'VLLM':
            self.llm = self.load_vllm_model()
        elif self.config['llm_framework'] == 'LLamaCpp':
            self.llm = self.load_llama_cpp_model()
        elif self.config['llm_framework'] == 'Ollama':
            self.llm = self.load_ollama_model()
            
            
    def load_vllm_model(self):
        # Load the vLLM model from HuggingFace Hub
        repo_id = self.config['repo_id']
        filename = self.config['filename']
        tokenizer = self.config['tokenizer']
        model_path = hf_hub_download(repo_id, filename=filename)
        
        # Initialize vLLM with the downloaded model
        vllm_llm = VLLM(model=model_path,
                        vllm_kwargs={"quantization": "awq", 
                                     'max_model_len': 8192,
                                     'gpu_memory_utilization': 0.7},
                        temperature=0.75,
                        stop=["<|eot_id|>"]
                        )
        
        return vllm_llm


    def load_llama_cpp_model(self):
        repo_id = self.config['repo_id']
        filename = self.config['filename']
        model_path = hf_hub_download(repo_id, filename=filename)
        
        # Инициализация модели LlamaCpp
        llama_cpp_llm = LlamaCpp(model_path=model_path,
                                temperature=0.8,
                                top_p=0.95,
                                top_k=30,
                                max_tokens=64,
                                n_ctx=13000,
                                n_parts=-1,
                                n_gpu_layers=64,
                                n_threads=8,
                                frequency_penalty=1.1,
                                verbose=True,
                                stop=["<|eot_id|>"],  # Остановка на токене EOS
                                )
        
        return llama_cpp_llm

    
    def load_ollama_model(self):
        model_name = self.config['repo_id']
        
        command = f"ollama pull {model_name}"
        
        try:
            subprocess.run(command, shell=True, check=True)
            print(f'Pullled the model {model_name} successfully')
        except subprocess.CalledProcessError as e:
            print(f"Error pulling model {model_name}: {e}")
        
        return OllamaLLM(
            model=model_name,
            temperature=0.8,
            top_p=0.95,
            top_k=30,
            max_tokens=512,
            stop=["<|eot_id|>"]
        )
    
    def load_and_process_documents(self):
        if (self.config['retriever_name'] == 'ensemble') \
            or (self.config['retriever_name'] == 'BM25') \
            or (self.config['compressor_name'] == 'gluing_chunks') \
            or (not self.vectorstore):

            loader = TextLoader(self.documents_path)
            documents = loader.load()
            
            # Split the documents into chunks
            text_splitter = CharacterTextSplitter(
                        separator=" ",
                        chunk_size=self.config['chunk_size'],
                        chunk_overlap=self.config['chunk_overlap'],
                        length_function=len,
                        is_separator_regex=False,
                    )
            texts = text_splitter.split_documents(documents)

            # Add chuck index to metadata to find neighborous-chunks after retrieving
            for index, document in enumerate(texts):
                document.metadata["chunk_index"] = index
            self.chunks = texts
            
            with open(self.chunks_path, "wb") as f:
                pickle.dump(self.chunks, f)
            
            if not self.vectorstore:
                if self.config['vectorstore_name'] == 'FAISS':
                    # Create a FAISS vector store from the documents
                    self.vectorstore = FAISS.from_documents(texts, self.embeddings)
                    self.vectorstore.save_local(self.vectorstore_path)
                elif self.config['vectorstore_name'] == 'MILVUS':
                    self.vectorstore = Milvus.from_documents(
                        texts,
                        self.embeddings,
                        collection_name="RAG",
                        connection_args={"uri": f"./{self.vectorstore_path}.db"})
    
    
    def init_retriever(self):        
        if self.config['retriever_name'] == 'ensemble':
            retrievers = []
            for retriever in self.config['ensemble_retrievers_names']:
                self.config['retriever_name'] = retriever
                retrievers.append(self.init_retriever())
                
            self.retriever = EnsembleRetriever(retrievers=retrievers,
                                              weights=self.config['ensemble_retrievers_weights'])
            self.config['retriever_name'] = 'ensemble'
            
        elif self.config['retriever_name'] == 'BM25':
            self.retriever = BM25Retriever.from_documents(documents=self.chunks)#, metadata=[chunk.metadata for chunk in self.chunks])
            self.retriever.k = self.config['retriever_k']

        elif self.config['retriever_name'] == 'vectorstore':
            self.retriever = self.vectorstore.as_retriever(search_kwargs={"k": self.config['retriever_k']})
        else:
            ValueError('Incorrect retriever name')
        
        return self.retriever
    
    
    def init_compressor(self):
        if self.config['compressor_name'] == 'gluing_chunks':
            # Инициализация класса компрессора
            self.compressor = ChunkCompressor(chunks=self.chunks, chunk_overlap=self.config['chunk_overlap'])
        elif self.config['compressor_name'] == 'cross_encoder_reranker':
            model = HuggingFaceCrossEncoder(model_name=self.config['reranker_model'])
            self.compressor = CrossEncoderReranker(model=model, top_n=4)
    
    
    def setup_qa_chain(self, custom_prompt: str = None):
        self.init_retriever()
        self.init_compressor()
        
        if self.compressor:            
            compression_retriever = ContextualCompressionRetriever(
                base_compressor=self.compressor, 
                base_retriever=self.retriever
            )
        else:
            compression_retriever = self.retriever
                
        prompt_template = PromptTemplate(
            input_variables=["context", "question"],
            template=custom_prompt
        )
        self.qa_chain = RetrievalQA.from_chain_type(
            llm=self.llm,
            chain_type=self.config['chain_type'],
            retriever=compression_retriever,
            return_source_documents=True,
            chain_type_kwargs={"prompt": prompt_template}
        )
    
    
    def query(self, question: str) -> Dict:
        if not self.qa_chain:
            raise ValueError("QA chain not set up. Call setup_qa_chain() first.")
        
        # Run the QA chain with the provided question
        return self.qa_chain({"query": question})



if __name__ == "__main__":
    # Initialize the pipeline
    rag_pipeline = CustomRAGPipeline(documents_path="hmao_npa.txt", config=config, recalc_embedding=False)
    
    # Load and process documents
    rag_pipeline.load_and_process_documents()
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling a086976afd4c... 100% ▕████████████████▏ 5.5 GB
# pulling c827688e53c8... 100% ▕████████████████▏  137 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 1f0c17ce1cdb... 100% ▕████████████████▏  118 B
# pulling 98f6e15c2efd... 100% ▕████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success
# Pullled the model mannix/gemma2-9b-simpo successfully

# %%
system_prompt = '''Use the following pieces of context to answer the question at the end. 
If you don't know the answer, just say that you don't know, don't try to make up an answer.
Think step by step. Give full answer. Answer only in Russian. If context doesnt match the answer, say that you do not know the answer.
{context}'''
user_prompt = '''Question: {question}
Answer:'''

custom_prompt = f"""
<|begin_of_text|>
<|start_header_id|>system<|end_header_id|>
{system_prompt}
<|eot_id|>
<|start_header_id|>user<|end_header_id|>
{user_prompt}
<|eot_id|>
<|start_header_id|>assistant<|end_header_id|>"""

rag_pipeline.setup_qa_chain(custom_prompt)

if __name__ == "__main__":
    queries = ["Какие условия и порядок оказания бесплатной медицинской помощи гражданам Российской Федерации в Ханты-Мансийском автономном округе - Югре?",
    # "Какие изменения внесли в закон N 176-оз в 2008 году?",
    # "Какое постановление Югры регулирует изменения в защите добровольных пожарных с 2017 года?",
    # "Какие мед. учреждения пострадают при сокращении финансирования?"
    ]
    for q in queries:
        result = rag_pipeline.query(q)
        print(result['result'], '\n')
    # result = rag_pipeline.query("Какие условия и порядок оказания бесплатной медицинской помощи гражданам Российской Федерации в Ханты-Мансийском автономном округе - Югре?")
    # result = rag_pipeline.query("Какие изменения внесли в закон N 176-оз в 2008 году?")
    # result = rag_pipeline.query("Какое постановление Югры регулирует изменения в защите добровольных пожарных с 2017 года?")
    # result = rag_pipeline.query('Какие мед. учреждения пострадают при сокращении финансирования?')
# Out:
# Бесплатная медицинская помощь гражданам РФ в Ханты-Мансийском автономном округе - Югре предоставляется в соответствии с **"Территориальной программой государственных гарантий оказания бесплатной медицинской помощи..."** и **действующим законодательством**.
#
# **Основные условия и порядок:**
#
# 1. **Амбулаторно-поликлинические учреждения:**
#    - Первая и неотложная помощь при острых состояниях оказывается **экстренно**.
#    - Лечащий врач определяет объем лечения по утвержденным стандартам.
#    - При плановой помощи возможна очередь, но максимальное ожидание консультаций и исследований **не превышает 10 дней**.
#
# 2. **Право выбора:**
#    - Граждане имеют право **выбрать врача** (в том числе семейного) и медицинскую организацию из утвержденного перечня.
#
# 3. **Специализированная помощь:**
#    -  В случае невозможности ее получения в округе, консультирование и лечение (включая санаторно-курортное) могут осуществляться в **медицинских НИИ и организациях** на территории РФ, по выбору в рамках программы.
#
# 4. **Финансирование:** Система **обязательного медицинского страхования** обеспечивает оплату медицинской и лекарственной помощи в объеме, установленном программой.  Дополнительная бесплатная помощь предоставляется  в рамках соцподдержки.
# 5. **Доступность:** Программа уделяет внимание обеспечению доступности помощи в **малонаселенных и отдаленных** районах.
#
#
# **Важно:**  Подробности о конкретных перечнях услуг, категориях граждан и нормативах финансирования изложены в полных текстах "Территориальной программы..." и соответствующих нормативных актов.

# %%
# для создания датасета для рагаса, потом удалить

def create_ragas_dataset(rag_pipeline, eval_dataset):
    rag_dataset = []
    for index, row in tqdm(eval_dataset.iterrows()):
        answer = rag_pipeline.query(row["question"])
        rag_dataset.append(
            {"question" : row["question"],
             "answer" : answer["result"],
             "contexts" : [context.page_content for context in answer["source_documents"]],
             "ground_truth" : row["ground_truth"]
             }
        )
    rag_df = pd.DataFrame(rag_dataset)
    rag_eval_dataset = Dataset.from_pandas(rag_df)
    return rag_eval_dataset

eval_dataset = pd.read_excel('v2_ragas_npa_dataset_firstPart.xlsx')
eval_dataset = eval_dataset.groupby('evolution_type', group_keys=False).apply(lambda x: x.sample(25, random_state=42)).copy()
# eval_df = create_ragas_dataset(rag_pipeline, eval_dataset)
eval_df = create_ragas_dataset(rag_pipeline, eval_dataset)
# Out:
# 100it [06:54,  4.15s/it]

# %%
def create_final_dataset(rag_pipeline, eval_dataset):
    rag_dataset = []
    for index, row in tqdm(eval_dataset.iterrows()):
        answer = rag_pipeline.query(row["question"])
        rag_dataset.append(
            {"question" : row["question"],
             'evolution_type': row['evolution_type'],
             "answer" : answer["result"],
             "contexts" : [context.page_content for context in answer["source_documents"]][:2],
             }
        )
    rag_df = pd.DataFrame(rag_dataset)
    rag_eval_dataset = Dataset.from_pandas(rag_df)
    return rag_eval_dataset

final_dataset = pd.read_excel('test_npa_itmo.xlsx')
# final_dataset = final_dataset.groupby('evolution_type', group_keys=False).apply(lambda x: x.sample(1, random_state=42)).copy()

rag_eval_dataset = create_final_dataset(rag_pipeline, final_dataset)

rag_df = rag_eval_dataset.to_pandas()


rag_df.to_excel('KVADR_test_npa_itmo.xlsx', index=False)
# Out:
# 0it [00:00, ?it/s]
# 17it [03:05, 10.29s/it]

# %%
eval_df['question']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 eval_df['question']
#
# NameError: name 'eval_df' is not defined

# %%
eval_df.save_to_disk('eval_df_baseline_new_5.2_gemma.hf')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
eval_df['ground_truth']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 eval_df['ground_truth']
#
# NameError: name 'eval_df' is not defined

# %%
from datasets import load_from_disk

test_df_ds = load_from_disk(f"evaluate_2.2.hf")

# %%
test_df_ds['question']
# Out:
# ['Когда юридические лица и ИП должны сообщать об аварийных выбросах?',
#  'Сколько дней на рассмотрение жалобы на отказ в приеме документов?',
#  'Зачем проводят конкурс среди оленеводов в ХМАО?',
#  'Как проводится внеплановая проверка в лесах при нарушении правил пожарной безопасности?',
#  'Какая защита у добровольных пожарных в ХМАО при увечьях?',
#  'Какой ОКТМО для свалки в муниципалитете?',
#  'Как рассчитывается срок предоставления услуги через МФЦ?',
#  'Какую долю занимают средства Нефтеюганск?',
#  'Что происходит с представительством от Правительства автономного округа в Совет Федерации, если представитель не может исполнять свои обязанности?',
#  'Что входит в ремонт подвала при реконструкции?',
#  'На что направлена субсидия на оборудование для больниц?',
#  'Какие целевые показатели для дорог в ХМАО - Югре с 2013 по 2030 год?',
#  'Как бороться с контрабандой в ХМАО-Югре?',
#  'Какую поддержку оказывает Департамент ЖКХ и энергетики Югры для энергосберегающих проектов?',
#  'Кто отвечает за информационную безопасность в ХМАО-Югре, если Губернатор отсутствует?',
#  'Какие требования к объекту капитального строительства?',
#  'Что может лишить граждан субсидии при переезде?',
#  'Какая зарплата в центрах занятости Югры при высшем образовании и стаже более 5 лет?',
#  'Где находится Когалымское месторождение нефти в ХМАО?',
#  'Как резерв кадров помогает в преемственности руководства в Ханты-Мансийске?',
#  'Где в Урае детские поликлиники с дневным стационаром?',
#  'Как переводится федеральный чин в округе?',
#  'Как регистрируется заявка работодателя, если работник под угрозой увольнения?',
#  'Какие военно-патриотические мероприятия в Югре связаны с ВОВ?',
#  'Что делают в ХМАО-Югре, если в общественных местах больше половины мест занято?',
#  'Что сделали с водоснабжением в Соруме с 2012 по 2013 год?',
#  'Какие условия для подписания Соглашения о переселении из аварийного жилищного фонда?',
#  'Что нужно для подтверждения проживания ребенка в Ханты-Мансийске и получения сертификата дополнительного образования?',
#  'Кто входит в состав Комиссии по предупреждению чрезвычайных ситуаций в Ханты-Мансийском автономном округе - Югре?',
#  'Что финансируется из местного бюджета на Севере?',
#  'Как рассчитать налоговую базу для нефтяных компаний в ХМАО-Югре?',
#  'Кто подписывает акт проверки в Природнадзоре Югры и на основании чего?',
#  'Зачем анализировать информацию о реализации программ и проектов?',
#  'Для чего предоставляется Субсидия на возмещение затрат на заготовленную продукцию охоты для коренных малочисленных народов Севера?',
#  'Цель Программы Ханты-Мансийского автономного округа - Югры по стабилизации ситуации на рынке труда на территории Югры на 2010 год, в части организации стажировки выпускников образовательных учреждений?\n\nМожно переписать вопрос более косвенно и кратко, сохраняя при этом суть исходного вопроса:\n\n"Что делает программа для выпускников в Югре в 2010 году?',
#  'Когда можно передать в долевую собственность жилое помещение по договору найма?',
#  'Где находится дом по ул. Космонавтов, д. N 3?',
#  'Зачем софинансировать образование в округе?',
#  'В какой бюджет идут штрафы за нарушение налогового законодательства?',
#  'Как рассчитать стоимость социальных услуг без госзаказа?',
#  'Как обрабатывается молоко из неблагополучных хозяйств?',
#  'Сколько средств из бюджета ХМАО-Югры выделяется на поддержку региональных операторов по обращению с ТКО?',
#  'Когда Правительство Ханты-Мансийского автономного округа - Югры приняло постановление N 328-п?',
#  'Сколько выделяется на "Кванториум" в сельской местности и малых городах?',
#  'Штрафы за нарушение законодательства РФ о госзакупках и куда идут денежные взыскания?',
#  'Какие проблемы с отходами в автономном округе?',
#  'Как представить доклад для публикации в сборнике?',
#  'Когда был принят Закон Ханты-Мансийского автономного округа - Югры?',
#  'Кто обслуживает портал госуслуг ХМАО?',
#  "Какая задача программы 'Развитие культуры и туризма в Ханты-Мансийском автономном округе - Югре на 2014 - 2020 годы' связана с сохранением культурного наследия?",
#  'Что включает раздел бюджета территориального фонда обязательного медицинского страхования?',
#  'Какие риски для программы доступности?',
#  'Сколько выделяется на студентов в федеральных университетах Югры?',
#  'Какой проект синхронизирует науку, образование и рынок труда в округе?',
#  'Как передаются полномочия по сельскохозяйственной переписи и как они финансируются?',
#  'Кто определяет порядок документооборота в исполнительных органах ХМАО?',
#  'Как утверждается план контрольных мероприятий?',
#  'Как Департамент размещает заказы и контракты?',
#  'Что изменилось в постановлении N 59 после постановления N 67?',
#  'В каких главах КоАП РФ штрафы за нарушения финансирования и аудита политических партий?',
#  'Кто контролирует выполнение распоряжения Правительства Ханты-Мансийского автономного округа - Югры от 20 июня 2007 г. N 237-рп?',
#  'Кто подписал закон № 67-оз в Ханты-Мансийске?',
#  'На каких законах основана Инструкция по делопроизводству в ХМАО - Югре?',
#  'Как изменились дороги округа после ремонта?',
#  'Что отменило постановление N 288 от 26 июня 1998 года?',
#  'Каков характер туристического потока в Нягани и Урае?',
#  'Из каких источников финансируются мероприятия по занятости населения?',
#  'Как финансируются дневные стационары?',
#  'Кто подписывает мотивированный запрос в Департаменте экономического развития Ханты-Мансийского автономного округа - Югры при проверке алкогольной продукции?',
#  'Какой год у Закона Ханты-Мансийского автономного округа - Югры от 25 февраля?',
#  'Кто контролирует государственные финансы?',
#  'Кто определяет загрязнение в мониторинге окружающей среды?',
#  'Какие КПЭ для финансовой поддержки госпрограмм в ХМАО-Югре?',
#  'Что изменилось в постановлении 341-п после постановления 63-п?',
#  'Какие обязанности у местных властей при заключении договора с частной образовательной организацией и как они определяют порядок предоставления субсидии?',
#  'Какие меры социальной поддержки в сфере здравоохранения установлены законодательством Ханты-Мансийского автономного округа?',
#  'Кто является главным редактором общественно-политической газеты "Новости Югры"?',
#  'Какие дополнительные мероприятия реализуются для снижения напряженности на рынке труда субъектов Российской Федерации?',
#  'Как рассчитываются средства бюджета автономного округа и бюджетов муниципальных образований автономного округа в рамках Программы обязательного медицинского страхования?',
#  'Какие изменения были внесены в постановление Губернатора Ханты-Мансийского автономного округа - Югры от 11 ноября 2005 года N 139 "О награждении и присвоении почетных званий"?',
#  'Какие этапы необходимо пройти для заключения договора безвозмездного срочного пользования лесным участком в соответствии с административным регламентом предоставления государственной услуги по предоставлению в пределах земель лесного фонда лесных участков в постоянное (бессрочное) пользование, аренду (без проведения аукциона), безвозмездное срочное пользование?',
#  'Кто несет ответственность за контроль за исполнением постановления Правительства Ханты-Мансийского автономного округа - Югры от 07.06.2004 № 243-п?',
#  'Какие работы по реконструкции и расширению здания Югорского политехнического колледжа были запланированы в период с 2011 по 2016 год?',
#  'В чем заключается цель целевой программы Ханты-Мансийского автономного округа - Югры "Дети Югры" на 2011 - 2015 годы?',
#  'Какое значение имеет экологическое образование в формировании экологической культуры в Ханты-Мансийском автономном округе - Югре?',
#  'Какую информацию предоставляет Природнадзор Югры по запросу организаций?',
#  'Какие меры профилактики правонарушений среди несовершеннолетних и молодежи планируется реализовать в рамках программы "Профилактика правонарушений в Ханты-Мансийском автономном округе - Югре на 2011 - 2013 годы"?',
#  'На основании каких документов и законов производится предоставление земельного участка в пользование?',
#  'Какие показатели, характеризующие количество отходов, отражаются в отчете по массе отходов?',
#  'Каким образом принимается решение о лишении организации, осуществляющей образовательную деятельность, государственной аккредитации?',
#  'Какие мероприятия проводятся в Ханты-Мансийском автономном округе - Югре для чествования ветеранов Великой Отечественной войны?',
#  'В чем заключается цель Постановления Правительства Ханты-Мансийского автономного округа - Югры от 19.04.2013 № 153-п, касающегося внесения изменений в постановление от 23 декабря 2010 года N 367-п "О целевой программе Ханты-Мансийского автономного округа - Югры "Профилактика экстремизма, гармонизация межэтнических и межкультурных отношений, укрепление толерантности в Ханты-Мансийском автономном округе - Югре на 2011 - 2015 годы"?',
#  'Какую роль играют инвестиционные проекты в Российской Федерации в развитии экономики Ханты-Мансийского автономного округа - Югры, в частности, в создании рабочих мест, росте ВВП и развитии инфраструктуры?',
#  'Какое значение имеет сохранение документального наследия в контексте государственной программы Ханты-Мансийского автономного округа - Югры по сохранению и популяризации культурного наследия?',
#  'Какие сферы деятельности автономного округа курирует Департамент образования и науки?',
#  'Какой порядок контроля за исполнением Административного регламента предоставления государственной услуги по аренде лесного участка, либо постоянного (бессрочного) пользования, либо безвозмездного срочного пользования?',
#  'Когда и где пройдет выездная лекция-концерт «С чего начинается Родина», организуемая Департаментом культуры и искусства автономного округа и учреждением автономного округа «Музей геологии, нефти и газа» в 2008 году?',
#  'Каков объем экспорта услуг категории "Поездки" в региональном проекте "Экспорт услуг" категории "Поездки" в Ханты-Мансийском автономном округе - Югре?',
#  'Каким образом реализация проектов, представленных муниципальными учреждениями на Конкурс, обеспечивается в муниципальном образовании автономного округа в рамках государственной программы?',
#  'Каков порядок действий в блок-схеме последовательности административных процедур при предоставлении лесных участков в границах земель лесного фонда?']

# %%
Какая защита у добровольных пожарных в ХМАО при увечьях?



Сколько дней на рассмотрение жалобы на отказ в приеме документов?



Когда юридические лица и ИП должны сообщать об аварийных выбросах?

# %%
from pymilvus import MilvusClient
client = MilvusClient("e5l_MILVUS_512_128.db")
client.describe_collection('RAG')
# Out:
# {'collection_name': 'RAG',
#  'auto_id': True,
#  'num_shards': 0,
#  'description': '',
#  'fields': [{'field_id': 100,
#    'name': 'source',
#    'description': '',
#    'type': <DataType.VARCHAR: 21>,
#    'params': {'max_length': 65535}},
#   {'field_id': 101,
#    'name': 'text',
#    'description': '',
#    'type': <DataType.VARCHAR: 21>,
#    'params': {'max_length': 65535}},
#   {'field_id': 102,
#    'name': 'pk',
#    'description': '',
#    'type': <DataType.INT64: 5>,
#    'params': {},
#    'auto_id': True,
#    'is_primary': True},
#   {'field_id': 103,
#    'name': 'vector',
#    'description': '',
#    'type': <DataType.FLOAT_VECTOR: 101>,
#    'params': {'dim': 1024}}],
#  'aliases': [],
#  'collection_id': 0,
#  'consistency_level': 0,
#  'properties': {},
#  'num_partitions': 0,
#  'enable_dynamic_field': False}
